# %% [markdown]
# ![image.png](attachment:fc9c9455-b10c-4d17-9839-6750779dab95.png)

# %% [markdown]
# ## ON 21/10/2025
# ## REG:24RP0842
# ## CAT OF MACHINE LEARNIG 1

# %% [markdown]
# # **House Price Regression Prediction🏠**
# ## Problem and rootcause Description
# In many cities, property prices change rapidly depending on factors such as number of bedrooms, size, number of bathroom, and nearby Neighborhood_Quality. People often struggle to estimate the fair value of a house or apartment. Using machine learning, we can build a model that predicts the price of a house based on thesefeatures.for accurate price prediction helps buyers to be informed and make decisions, prevents overpricing by sellers, and supports real estate companies in offering fair market values. It benefits to banks and investors in assessing property risks and loan amounts approval. This problem is real, relevant, and well-suited for regression models in machine learning.
# ## **For a Dataset Description here wehave some features which is prediction place takes for**
# 1. **Square_Footage**: The size of the house in square feet. Larger homes typically have higher prices.
# 2. **Num_Bedrooms**: The number of bedrooms in the house. More bedrooms generally increase the value of a home.
# 3. **Num_Bathrooms**: The number of bathrooms in the house. Houses with more bathrooms are typically priced higher.
# 4. **Year_Built**: The year the house was built. Older houses may be priced lower due to wear and tear.
# 5. **Lot_Size**: The size of the lot the house is built on, measured in acres. Larger lots tend to add value to a property.
# 6. **Garage_Size**: The number of cars that can fit in the garage. Houses with larger garages are usually more expensive.
# 7. **Neighborhood_Quality**: A rating of the neighborhood’s quality on a scale of 1-10, where 10 indicates a high-quality neighborhood. Better neighborhoods usually command higher prices.
# 8. **House_Price (Target Variable)**: The price of the house, which is the dependent variable you aim to predict.

# %% [markdown]
# ## here we need to loading our dataset into juppiter notebook this two libraries pandas and numpy its will help us to do that task

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv('house_price_regression_datasete.csv')      #https://www.kaggle.com/datasets/prokshitha/home-value-insights

# %% [markdown]
#  ## Link of my dataset from kaggle
#  https://www.kaggle.com/datasets/prokshitha/home-value-insights

# %%
df
# Out:
#      Square_Footage  Num_Bedrooms  Num_Bathrooms  Year_Built  Lot_Size  \
# 0              1360             2              1        1981  0.599637
# 1              4272             3              3        2016  4.753014
# 2              3592             1              2        2016  3.634823
# 3               966             1              2        1977  2.730667
# 4              4926             2              1        1993  4.699073
# ..              ...           ...            ...         ...       ...
# 995            3261             4              1        1978  2.165110
# 996            3179             1              2        1999  2.977123
# 997            2606             4              2        1962  4.055067
# 998            4723             5              2        1950  1.930921
# 999            3268             4              2        1983  3.108790
#
#      Garage_Size  Neighborhood_Quality   House_Price
# 0              0                     5  2.623829e+05
# ...

# %% [markdown]
# ## Basic Stats
# here in my dataset i need some basics chacking through my dataframe, by checking in my head,shape,colums,info, and discriptions my dataset

# %%
df.head()      ## here head is showing me how my dataset looklike for first five lines
# Out:
#    Square_Footage  Num_Bedrooms  Num_Bathrooms  Year_Built  Lot_Size  \
# 0            1360             2              1        1981  0.599637
# 1            4272             3              3        2016  4.753014
# 2            3592             1              2        2016  3.634823
# 3             966             1              2        1977  2.730667
# 4            4926             2              1        1993  4.699073
#
#    Garage_Size  Neighborhood_Quality   House_Price
# 0            0                     5  2.623829e+05
# 1            1                     6  9.852609e+05
# 2            0                     9  7.779774e+05
# 3            1                     8  2.296989e+05
# 4            0                     8  1.041741e+06

# %%
df.shape      ## here shaping is helps me to count num of rows and colums containing my dataset
# Out:
# (1000, 8)

# %%
df.columns    ## here we need to number of colums only
# Out:
# Index(['Square_Footage', 'Num_Bedrooms', 'Num_Bathrooms', 'Year_Built',
#        'Lot_Size', 'Garage_Size', 'Neighborhood_Quality', 'House_Price'],
#       dtype='object')

# %%
df.describe()  ### here i need to see statistical analysis and this command gives me a statistical summary of my numerical columns in the dataset.
# Out:
#        Square_Footage  Num_Bedrooms  Num_Bathrooms   Year_Built     Lot_Size  \
# count     1000.000000   1000.000000    1000.000000  1000.000000  1000.000000
# mean      2815.422000      2.990000       1.973000  1986.550000     2.778087
# std       1255.514921      1.427564       0.820332    20.632916     1.297903
# min        503.000000      1.000000       1.000000  1950.000000     0.506058
# 25%       1749.500000      2.000000       1.000000  1969.000000     1.665946
# 50%       2862.500000      3.000000       2.000000  1986.000000     2.809740
# 75%       3849.500000      4.000000       3.000000  2004.250000     3.923317
# max       4999.000000      5.000000       3.000000  2022.000000     4.989303
#
#        Garage_Size  Neighborhood_Quality   House_Price
# count  1000.000000           1000.000000  1.000000e+03
# mean      1.022000              5.615000  6.188610e+05
# std       0.814973              2.887059  2.535681e+05
# ...

# %%
df.info()# here we need to be infoermed to how my dataset is  by loking if there is no null colums and That output is the summary of my dataset after using the command,and also my data is stored in a DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Square_Footage        1000 non-null   int64
#  1   Num_Bedrooms          1000 non-null   int64
#  2   Num_Bathrooms         1000 non-null   int64
#  3   Year_Built            1000 non-null   int64
#  4   Lot_Size              1000 non-null   float64
#  5   Garage_Size           1000 non-null   int64
#  6   Neighborhood_Quality  1000 non-null   int64
#  7   House_Price           1000 non-null   float64
# dtypes: float64(2), int64(6)
# memory usage: 62.6 KB

# %% [markdown]
# ## check null values

# %%
df.isna().sum()
# Out:
# Square_Footage          0
# Num_Bedrooms            0
# Num_Bathrooms           0
# Year_Built              0
# Lot_Size                0
# Garage_Size             0
# Neighborhood_Quality    0
# House_Price             0
# dtype: int64

# %% [markdown]
# ## print the number of duplicate values

# %%
print("the number of duplicate values:", df.duplicated().sum())
# Out:
# the number of duplicate values: 0

# %% [markdown]
# ## to remove the null values

# %%
df=df.dropna()
df
# Out:
#      Square_Footage  Num_Bedrooms  Num_Bathrooms  Year_Built  Lot_Size  \
# 0              1360             2              1        1981  0.599637
# 1              4272             3              3        2016  4.753014
# 2              3592             1              2        2016  3.634823
# 3               966             1              2        1977  2.730667
# 4              4926             2              1        1993  4.699073
# ..              ...           ...            ...         ...       ...
# 995            3261             4              1        1978  2.165110
# 996            3179             1              2        1999  2.977123
# 997            2606             4              2        1962  4.055067
# 998            4723             5              2        1950  1.930921
# 999            3268             4              2        1983  3.108790
#
#      Garage_Size  Neighborhood_Quality   House_Price
# 0              0                     5  2.623829e+05
# ...

# %% [markdown]
# ## Creating independent and dependent variable

# %%
x = df[['Square_Footage','Num_Bedrooms','Num_Bathrooms','Year_Built','Lot_Size','Garage_Size','Neighborhood_Quality']]

# %%
x
# Out:
#      Square_Footage  Num_Bedrooms  Num_Bathrooms  Year_Built  Lot_Size  \
# 0              1360             2              1        1981  0.599637
# 1              4272             3              3        2016  4.753014
# 2              3592             1              2        2016  3.634823
# 3               966             1              2        1977  2.730667
# 4              4926             2              1        1993  4.699073
# ..              ...           ...            ...         ...       ...
# 995            3261             4              1        1978  2.165110
# 996            3179             1              2        1999  2.977123
# 997            2606             4              2        1962  4.055067
# 998            4723             5              2        1950  1.930921
# 999            3268             4              2        1983  3.108790
#
#      Garage_Size  Neighborhood_Quality
# 0              0                     5
# ...

# %%
y=df[['House_Price']]

# %%
y
# Out:
#       House_Price
# 0    2.623829e+05
# 1    9.852609e+05
# 2    7.779774e+05
# 3    2.296989e+05
# 4    1.041741e+06
# ..            ...
# 995  7.014940e+05
# 996  6.837232e+05
# 997  5.720240e+05
# 998  9.648653e+05
# 999  7.425993e+05
#
# [1000 rows x 1 columns]

# %% [markdown]
# ## Splitting train and test

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(x,y, test_size=0.2, random_state=42)

# %%
x_train
# Out:
#      Square_Footage  Num_Bedrooms  Num_Bathrooms  Year_Built  Lot_Size  \
# 29             2028             2              3        1967  1.784790
# 535            3519             5              3        1966  4.009947
# 695            4507             2              3        2014  4.122337
# 557            3371             4              2        2000  1.580318
# 836            2871             5              1        1974  3.426914
# ..              ...           ...            ...         ...       ...
# 106            2257             5              1        1968  3.131006
# 270            3894             3              2        1975  1.256532
# 860            1484             5              1        2010  1.246555
# 435            1865             4              2        1994  4.354220
# 102            1363             4              1        1977  4.408878
#
#      Garage_Size  Neighborhood_Quality
# 29             2                     2
# ...

# %% [markdown]
# ##  by now after exploration our daraset we are going to Creating a Regression Model

# %% [markdown]
# ## Selecting and Fitting the Model

# %%
#from sklearn.linear_model import LinearRegression

#lr_model = LinearRegression()
#lr_model.fit(X_train, y_train)
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor(random_state=42)
model.fit(x_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
y_pred = model.predict(x_test)
print(y_pred)
# Out:
# [ 853113.07057188  508320.33881301  946921.29991625 1029746.43355362
#   798249.15487281  737715.66246639  981860.08161387  878651.42323665
#   816590.23953134  926487.73413295  749450.48060998  652516.1230017
#   231527.40771636 1040898.54028262  552113.99119296  217018.75782637
#   469685.94425428  383219.06664945  735655.46644969  359228.45051109
#   769291.22273273  498286.45767429  698344.82375103  882916.29318646
#   432043.81585571  369245.61346643  461955.67807412  438839.78314317
#   217998.68515217  458690.81801879  253696.75720396  903855.77808263
#   755164.6506346   351186.44529351  489695.17781207  761561.88333579
#   463780.33985924  586960.84794815  274496.34785753  149432.82112821
#   307595.7735478   277372.72645744  502786.22494467  316482.26309059
#  1082155.61793351  982616.64735683  773300.83941832  818160.51572428
#   998871.4021493   714829.51917021  270739.3441286   750475.13855932
#   812522.88813517  684064.3276854   527196.7166908   804534.67565476
# ...

# %% [markdown]
# ## To print the accuracy of model

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
y_pred = model.predict(x_test)

print("MAE:", mean_absolute_error(y_test, y_pred))
print("MSE:", mean_squared_error(y_test, y_pred))
print("R²:", r2_score(y_test, y_pred))
# Out:
# MAE: 16114.289643937647
# MSE: 394131747.44603425
# R²: 0.9938855300068556

# %%
print('The accuracy of house predicted model is', (r2_score(y_test, y_pred)*100))
# Out:
# The accuracy of house predicted model is 99.38855300068556

# %% [markdown]
# ## Testing prediction with examples by unseen date enference

# %% [markdown]
# # Define your new house as a DataFrame

# %%
import pandas as pd

# Define your new house as a DataFrame
new_house = pd.DataFrame([{
    'Square_Footage': 1360,
    'Num_Bedrooms': 2,
    'Num_Bathrooms': 1,
    'Year_Built':1981,
    'Lot_Size': 0.59963664,
    'Garage_Size': 0,
    'Neighborhood_Quality': 5,
    
}])

# %%
new_house
# Out:
#    Square_Footage  Num_Bedrooms  Num_Bathrooms  Year_Built  Lot_Size  \
# 0            1360             2              1        1981  0.599637
#
#    Garage_Size  Neighborhood_Quality
# 0            0                     5

# %%
predicted_house = model.predict(new_house)
print("Predicted Price for new house:", predicted_house[0])
# Out:
# Predicted Price for new house: 281935.7084194885

# %% [markdown]
# ## EDA (Exploratory Data Analysis)
# here we are Looking at our dataset carefully to understand it before building any model, It help me to See what our data looks like (rows, columns, values) and help me to Find patterns or trends (e.g., house price goes up when NUM_bedrooms increase) but also help us to Detect problems (missing values, duplicates, wrong data) and Visualize relationships using graphs and charts.
#
# ## Visualizations¶
# by data visualization we will need to import different libraries which will help us to see my data and to analyising of each colums through out of my data set with it's frequently and size on the groaph

# %%
import seaborn as sns
import matplotlib.pyplot as plt

def create_histplot(data, column):
    plt.figure(figsize=(6,4))
    sns.histplot(data[column], kde=True)
    plt.title(f'Histogram of {column}')
    plt.show()

# %%
for col in df.columns:
  create_histplot(df, col)

# %%
df.mean()
# Out:
# Square_Footage            2815.422000
# Num_Bedrooms                 2.990000
# Num_Bathrooms                1.973000
# Year_Built                1986.550000
# Lot_Size                     2.778087
# Garage_Size                  1.022000
# Neighborhood_Quality         5.615000
# House_Price             618861.018647
# dtype: float64

# %%
df.std()
# Out:
# Square_Footage            1255.514921
# Num_Bedrooms                 1.427564
# Num_Bathrooms                0.820332
# Year_Built                  20.632916
# Lot_Size                     1.297903
# Garage_Size                  0.814973
# Neighborhood_Quality         2.887059
# House_Price             253568.058375
# dtype: float64

# %%
df.isnull().sum()  ###### here isnull it's will help us to see if there is any missed data in columes or duplicated data
# Out:
# Square_Footage          0
# Num_Bedrooms            0
# Num_Bathrooms           0
# Year_Built              0
# Lot_Size                0
# Garage_Size             0
# Neighborhood_Quality    0
# House_Price             0
# dtype: int64

# %% [markdown]
# # Correlation¶
#
# here we want to measures how strongly two variables xand y move together. will see if there is  Positive correlation by one value increases, the other tends to increase too while Negative correlation by also one value increases, the other tends to decrease. but by 0 correlation shows No relationship between my x and y. by passing through my data set as foer enstance here If House Age increases and House Price decreases, that means there is negative correlation but If House Age increases and House Price also increases that would be positive correlation.

# %%
df.corr()### here you see by df.corr we found range of -1 to 1 means our carralation vallies between this range
# Out:
#                       Square_Footage  Num_Bedrooms  Num_Bathrooms  Year_Built  \
# Square_Footage              1.000000     -0.043564      -0.031584   -0.022392
# Num_Bedrooms               -0.043564      1.000000       0.022848   -0.015820
# Num_Bathrooms              -0.031584      0.022848       1.000000   -0.021063
# Year_Built                 -0.022392     -0.015820      -0.021063    1.000000
# Lot_Size                    0.089479     -0.009355       0.034923   -0.061050
# Garage_Size                 0.030593      0.113761       0.024846   -0.025485
# Neighborhood_Quality       -0.008357     -0.049024       0.017585   -0.009549
# House_Price                 0.991261      0.014633      -0.001862    0.051967
#
#                       Lot_Size  Garage_Size  Neighborhood_Quality  House_Price
# Square_Footage        0.089479     0.030593             -0.008357     0.991261
# Num_Bedrooms         -0.009355     0.113761             -0.049024     0.014633
# ...

# %%
plt.figure(figsize=(10, 7))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.show()

# %%
df.corr()['House_Price'].sort_values(ascending=False) ### by here we trying to ascending and sorting our corr by relationship of our features and house price
# Out:
# House_Price             1.000000
# Square_Footage          0.991261
# Lot_Size                0.160412
# Garage_Size             0.052133
# Year_Built              0.051967
# Num_Bedrooms            0.014633
# Num_Bathrooms          -0.001862
# Neighborhood_Quality   -0.007770
# Name: House_Price, dtype: float64

# %%
sns.pairplot(df, corner=True)
plt.show()### here we want to see how our data are correlated and this creates a pairplot using by using Seaborn, which shows me a Scatter plots between every pair of numerical features

# %%
def outlier_detection(data, column):
  # plt.figure(figsize=(8, 8))
  sns.boxplot(x=data[column])
  plt.title(f"Boxplot of {column}")
  # plt.ylabel(f"{column}")
  plt.xlabel("Frequency")
  plt.show()

# %%
for col in df.columns:
  outlier_detection(df, col) ### checking if there is any outliers in my data each colum is has own graph

# %% [markdown]
# ## saving house prediction model

# %%
import pickle
filename = 'house_sales_data.sav'
pickle.dump(model, open (filename,'wb'))

# %%
# Define your new house as a DataFrame
new_house = pd.DataFrame([{
    'Square_Footage': 1360,
    'Num_Bedrooms': 2,
    'Num_Bathrooms': 1,
    'Year_Built':1981,
    'Lot_Size': 0.59963664,
    'Garage_Size': 0,
    'Neighborhood_Quality': 5,
    
}])

# %%
new_house
# Out:
#    Square_Footage  Num_Bedrooms  Num_Bathrooms  Year_Built  Lot_Size  \
# 0            1360             2              1        1981  0.599637
#
#    Garage_Size  Neighborhood_Quality
# 0            0                     5

# %%
predicted_house = model.predict(new_house)
print("Predicted Price for new house:", predicted_house[0])
# Out:
# Predicted Price for new house: 281935.7084194885
